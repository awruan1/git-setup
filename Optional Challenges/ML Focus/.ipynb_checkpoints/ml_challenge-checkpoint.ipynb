# %% [markdown]
# # ML Challenge (Optional)

# %% [markdown]
# Train, test, optimize, and analyze the performance of a classification model using a methodology of your choice for the randomly generated moons dataset.
#
# You are not being evaluated for the performance of your model. Instead, we are interested in whether you can implement a simple but rigorous ML workflow.
#
# Show all of your work in this notebook.

# %% [markdown]
# I used https://medium.com/@kbrook10/day-11-machine-learning-using-knn-k-nearest-neighbors-with-scikit-learn-350c3a1402e6, https://laxmikants.github.io/blog/neural-network-using-make-moons-dataset/, and https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html. I've used pytorch but not sklearn so those links helped a lot.
#
# KNN came to mind first, but testing with other models could be another optimization step.

# %%
# you are free to use any package you deem fit
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 

from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# %% [markdown]
# ## Dataset

# %%
# DO NOT MODIFY
from sklearn.datasets import make_moons

X, Y = make_moons(random_state=42, n_samples=(50, 450), noise=0.25)

print(X.shape)
print(Y.shape)
# Out:
# (500, 2)
# (500,)

# %% [markdown]
# ## Training

# %% [markdown]
# No validation, just training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.3, random_state=0)

# %% [markdown]
# Training first with KNN Classifier with 3 neighbors

# %%
model = KNeighborsClassifier(3).fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 0.98

# %% [markdown]
# ## Testing / Optimization

# %%
y_pred = model.predict(X_test)
print(model.score(X_test, y_test))
# Out:
# 0.94

# %% [markdown]
# Checking error to find better number of neighbors (above training accuracy is definitely than testing accuracy)

# %%
error_rate = []
for i in range(1,30):
    
    model = KNeighborsClassifier(n_neighbors=i)
    model.fit(X_train, y_train)
    pred_i = model.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(10,4))
plt.plot(range(1,30), error_rate, color='black', marker='.', markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K-Values')
plt.xlabel('K-Values')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# 10 neighbors could work well with this model. Anywhere between 5 and 15 looks reasonable.

# %%
model = KNeighborsClassifier(10).fit(X_train, y_train)
print(model.score(X_train, y_train))
# Out:
# 0.9742857142857143

# %%
y_pred = model.predict(X_test)
print(model.score(X_test, y_test))
# Out:
# 0.9533333333333334

# %% [markdown]
# ## Performance Analysis

# %%
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.65      0.76        17
#            1       0.96      0.99      0.97       133
#
#     accuracy                           0.95       150
#    macro avg       0.94      0.82      0.87       150
# weighted avg       0.95      0.95      0.95       150

# %%
cmat = metrics.confusion_matrix(y_test, y_pred)
print('True Negative: {}'.format(cmat[0,0]))
print('False Positive: {}'.format(cmat[0,1]))
print('False Negative: {}'.format(cmat[1,0]))
print('True Positive: {}'.format(cmat[1,1]))
print('Accuracy Rate: {}'.format(np.divide(np.sum([cmat[0,0],cmat[1,1]]),np.sum(cmat))))
print('Misclassification Rate: {}'.format(np.divide(np.sum([cmat[0,1],cmat[1,0]]),np.sum(cmat))))
# Out:
# True Negative: 11
# False Positive: 6
# False Negative: 1
# True Positive: 132
# Accuracy Rate: 0.9533333333333334
# Misclassification Rate: 0.04666666666666667

# %% [markdown]
# We can observe high classification accuracy with both training (around 97%) and testing (around 95%) using a KNN Classifier with 10 neighbors.
